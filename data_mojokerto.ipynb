# %% [markdown]
# <a href="https://colab.research.google.com/github/sylviatobing/TUGAS8_VIS.DATA/blob/main/data_mojokerto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df = pd.read_csv('data-penduduk-mojokerto.csv')
df.head()
# Out:
#      propinsi        kab_kota  tahun       kecamatan       kelurahan  \
# 0  Jawa_Timur  Kota_Mojokerto   2016  Prajurit_Kulon        Mentikan
# 1  Jawa_Timur  Kota_Mojokerto   2016  Prajurit_Kulon          Kauman
# 2  Jawa_Timur  Kota_Mojokerto   2016  Prajurit_Kulon        Pulorejo
# 3  Jawa_Timur  Kota_Mojokerto   2016  Prajurit_Kulon  Prajurit_kulon
# 4  Jawa_Timur  Kota_Mojokerto   2016  Prajurit_Kulon     Surodinawan
#
#    kelahiran  kematian  mutasi_datang  mutasi_keluar
# 0         87        61             84            108
# 1         50        25             59             52
# 2        122        71            170             68
# 3        122        52            164             84
# 4        129        42            271            119

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   propinsi       18 non-null     object
#  1   kab_kota       18 non-null     object
#  2   tahun          18 non-null     int64
#  3   kecamatan      18 non-null     object
#  4   kelurahan      18 non-null     object
#  5   kelahiran      18 non-null     int64
#  6   kematian       18 non-null     int64
#  7   mutasi_datang  18 non-null     int64
#  8   mutasi_keluar  18 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.4+ KB

# %%
for column in df.columns:
    print(f"{column}: Number of unique values {df[column].nunique()}")
    print("==========================================================")
# Out:
# propinsi: Number of unique values 1
# ...
# kab_kota: Number of unique values 1
# ...
# tahun: Number of unique values 1
# ...
# kecamatan: Number of unique values 3
# ...
# kelurahan: Number of unique values 18
# ...
# kelahiran: Number of unique values 16
# ...
# kematian: Number of unique values 16
# ...
# mutasi_datang: Number of unique values 18
# ...
# mutasi_keluar: Number of unique values 18
# ...

# %%
df.describe()
# Out:
#         tahun   kelahiran    kematian  mutasi_datang  mutasi_keluar
# count    18.0   18.000000   18.000000      18.000000      18.000000
# mean   2016.0   96.833333   78.333333     149.388889     117.666667
# std       0.0   73.308574   52.218996      94.975625      88.261643
# min    2016.0   11.000000   25.000000      23.000000      28.000000
# 25%    2016.0   51.500000   41.250000      65.250000      62.750000
# 50%    2016.0   81.500000   57.500000     141.500000      93.000000
# 75%    2016.0  122.000000  103.000000     181.250000     128.750000
# max    2016.0  279.000000  207.000000     342.000000     392.000000

# %%
sns.barplot(data=df , x="kelahiran" , y="kelurahan")
# Out:
# <Axes: xlabel='kelahiran', ylabel='kelurahan'>

# %%
sns.barplot(data=df , x="kematian" , y="kelurahan")
# Out:
# <Axes: xlabel='kematian', ylabel='kelurahan'>

# %%
sns.barplot(data=df , x="kecamatan" , y="kelahiran")
# Out:
# <Axes: xlabel='kecamatan', ylabel='kelahiran'>

# %%
sns.barplot(data=df , x="kecamatan" , y="kematian")
# Out:
# <Axes: xlabel='kecamatan', ylabel='kematian'>

# %%
sns.boxplot(data=df , x="kecamatan" , y="kelahiran")
# Out:
# <Axes: xlabel='kecamatan', ylabel='kelahiran'>

# %%
sns.boxplot(data=df , x="kecamatan" , y="kematian")
# Out:
# <Axes: xlabel='kecamatan', ylabel='kematian'>

# %%
sns.barplot(data=df, x="kecamatan" , y="mutasi_datang")
# Out:
# <Axes: xlabel='kecamatan', ylabel='mutasi_datang'>

# %%
sns.barplot(data=df, x="kecamatan" , y="mutasi_keluar")
# Out:
# <Axes: xlabel='kecamatan', ylabel='mutasi_keluar'>

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# <ipython-input-19-6522c2b4e5f9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
